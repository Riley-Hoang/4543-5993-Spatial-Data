# %% [markdown]
# ## Lines and Distances
#
# ### Goal
#
# Last lesson we loaded the WDO package and used some of the  given spatial functions. Now we are going to put package to use  and calculate many more  distances and draw some lines. There is a file with many many cities world wide. I would like you to read the file and calculate distances from Wichita Falls Tx (MSU campus) to all the cites in the world. Well ... most of them ... that have people ... and are in my file. I mean Burkburnett probably isn't in the file, but it has people, so ... whatever. Still a cool file. (update ... I just checked, and Burk is in the file)
#
# ### Tasks
#
# - Read in a file containing the locations to cities all over the world ([world_cities_large.json](./../data/world_cities_large.json)).
# - Draw a line from MSU (or close to it) to each city in the file.
# - This file has way too many cities, cut it back to something smaller by filtering by time zones.
#
#
# Before you load the entire file, here is a small test object with a list of cities.
#
# ```json
# [
#     {
#       "city-name": "Paris",
#       "country-code": "FR",
#       "lat": "48.85341",
#       "lon": "2.3488",
#       "time-zone": "Europe/Paris"
#     },
#         {
#       "city-name": "London",
#       "country-code": "GB",
#       "lat": "51.50853",
#       "lon": "-0.12574",
#       "time-zone": "Europe/London"
#     },
#     {
#       "city-name": "Tokyo",
#       "country-code": "JP",
#       "lat": "35.6895",
#       "lon": "139.69171",
#       "time-zone": "Asia/Tokyo"
#     },
#     {
#       "city-name": "Tachikawa",
#       "country-code": "JP",
#       "lat": "35.71410661" ,
#       "lon": "139.40781784",
#       "time-zone": "Asia/Tokyo"
#     },
#     {
#       "city-name": "Rio de Janeiro",
#       "country-code": "BR",
#       "lat": "-22.90278",
#       "lon": "-43.2075",
#       "time-zone": "America/Sao_Paulo"
#     }
# ]
# ```
#
# Is this object helpful?  If you were to create your own file, what should you consider? The only worry is calculating correct answers, so however you check and verify, you  should just make sure the answers are correct and make sense.
#
# **FYI: **
#
# This micro lesson uses code from these two:
# - [03-Style_W_Logic](./03-Style_W_Logic.ipynb)
# - [04-Distance](./04-Distance.ipynb)

# %%
# Out:
# 48.85341 2.3488
# Location for: Paris = [lat:48.85341,lon:2.3488]
